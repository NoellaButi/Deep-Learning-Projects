# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/CS310/
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/CS310

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-gidf0zm8
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-gidf0zm8
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=91e20e5cb5c7966209ef7b16aaa377916837e510357fe7470cadaacdd38333f1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dpkcrlvo/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding="valid"), # 1D Conv Layer 1
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"), # 1D Conv Layer 2
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"), # 1D Conv Layer 3
    nn.ReLU(),
    nn.Flatten(), # Converts shape (4,15) to (60)
    nn.Linear(60, 10) # Fully Connected Layer (Input=60, Output=10)
)
#nn.Flatten(),
#nn.Linear(40, 100),
#nn.ReLU(),
#nn.Linear(100, 100),
#nn.ReLU(),
#nn.Linear(100, 10))

# Print model architecture
print(model)
# Out:
# Sequential(
#   (0): Conv1d(1, 15, kernel_size=(3,), stride=(2,), padding=valid)
#   (1): ReLU()
#   (2): Conv1d(15, 15, kernel_size=(3,), stride=(2,), padding=valid)
#   (3): ReLU()
#   (4): Conv1d(15, 15, kernel_size=(3,), stride=(2,), padding=valid)
#   (5): ReLU()
#   (6): Flatten(start_dim=1, end_dim=-1)
#   (7): Linear(in_features=60, out_features=10, bias=True)
# )

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.935028, train error 76.30,  val loss 1.940913, percent error 78.10
# Epoch     1, train loss 1.554565, train error 62.45,  val loss 1.582546, percent error 65.60
# Epoch     2, train loss 1.370199, train error 53.45,  val loss 1.395289, percent error 56.70
# Epoch     3, train loss 1.328489, train error 56.85,  val loss 1.330352, percent error 58.20
# Epoch     4, train loss 1.107684, train error 43.83,  val loss 1.125606, percent error 46.90
# Epoch     5, train loss 0.991624, train error 39.55,  val loss 1.034243, percent error 43.10
# Epoch     6, train loss 0.914270, train error 37.30,  val loss 0.970786, percent error 39.60
# Epoch     7, train loss 0.793484, train error 31.88,  val loss 0.841860, percent error 34.20
# Epoch     8, train loss 0.719221, train error 29.18,  val loss 0.778268, percent error 32.70
# Epoch     9, train loss 0.836816, train error 33.45,  val loss 0.901717, percent error 35.40
# Epoch    10, train loss 0.634564, train error 25.78,  val loss 0.702986, percent error 27.70
# Epoch    11, train loss 0.687301, train error 27.35,  val loss 0.795377, percent error 30.30
# Epoch    12, train loss 0.575632, train error 23.22,  val loss 0.673506, percent error 26.70
# Epoch    13, train loss 0.449709, train error 17.12,  val loss 0.531308, percent error 21.20
# Epoch    14, train loss 0.606052, train error 22.82,  val loss 0.687500, percent error 25.90
# Epoch    15, train loss 0.455458, train error 17.60,  val loss 0.586242, percent error 22.00
# Epoch    16, train loss 0.404495, train error 15.28,  val loss 0.497661, percent error 17.50
# Epoch    17, train loss 0.366938, train error 13.97,  val loss 0.430889, percent error 15.20
# Epoch    18, train loss 0.309568, train error 11.60,  val loss 0.415875, percent error 15.20
# Epoch    19, train loss 0.302283, train error 11.80,  val loss 0.420691, percent error 16.20
# Epoch    20, train loss 0.222186, train error 8.03,  val loss 0.329841, percent error 11.90
# Epoch    21, train loss 0.195657, train error 6.70,  val loss 0.326706, percent error 11.70
# Epoch    22, train loss 0.218754, train error 8.22,  val loss 0.342443, percent error 12.10
# Epoch    23, train loss 0.213509, train error 7.65,  val loss 0.352648, percent error 12.40
# Epoch    24, train loss 0.174258, train error 6.25,  val loss 0.301862, percent error 11.20
# Epoch    25, train loss 0.157434, train error 5.40,  val loss 0.300998, percent error 10.50
# Epoch    26, train loss 0.179944, train error 6.40,  val loss 0.346004, percent error 11.10
# Epoch    27, train loss 0.161421, train error 5.50,  val loss 0.318845, percent error 11.50
# Epoch    28, train loss 0.155003, train error 5.32,  val loss 0.312419, percent error 10.20
# Epoch    29, train loss 0.150267, train error 5.28,  val loss 0.307461, percent error 10.30
# Epoch    30, train loss 0.127563, train error 4.10,  val loss 0.301291, percent error 9.30
# Epoch    31, train loss 0.173757, train error 6.22,  val loss 0.346054, percent error 10.20
# Epoch    32, train loss 0.132872, train error 4.40,  val loss 0.308810, percent error 9.60
# Epoch    33, train loss 0.125196, train error 4.53,  val loss 0.293935, percent error 10.30
# Epoch    34, train loss 0.109888, train error 3.65,  val loss 0.305831, percent error 9.50
# Epoch    35, train loss 0.101955, train error 3.15,  val loss 0.304562, percent error 10.20
# Epoch    36, train loss 0.096498, train error 3.05,  val loss 0.303958, percent error 10.00
# Epoch    37, train loss 0.115531, train error 4.00,  val loss 0.315160, percent error 10.10
# Epoch    38, train loss 0.104846, train error 3.53,  val loss 0.311976, percent error 9.20
# Epoch    39, train loss 0.103216, train error 3.35,  val loss 0.307488, percent error 9.90
# Epoch    40, train loss 0.077539, train error 2.25,  val loss 0.293446, percent error 9.00
# Epoch    41, train loss 0.079701, train error 2.47,  val loss 0.295156, percent error 9.70
# Epoch    42, train loss 0.070317, train error 1.82,  val loss 0.295139, percent error 8.90
# Epoch    43, train loss 0.068752, train error 2.05,  val loss 0.301315, percent error 8.60
# Epoch    44, train loss 0.064446, train error 1.55,  val loss 0.300731, percent error 8.60
# Epoch    45, train loss 0.067112, train error 1.88,  val loss 0.313230, percent error 9.10
# Epoch    46, train loss 0.064854, train error 1.88,  val loss 0.316609, percent error 8.80
# Epoch    47, train loss 0.061417, train error 1.75,  val loss 0.305388, percent error 8.80
# Epoch    48, train loss 0.060599, train error 1.47,  val loss 0.316976, percent error 9.30
# Epoch    49, train loss 0.059437, train error 1.35,  val loss 0.310260, percent error 9.10
# Epoch    50, train loss 0.058866, train error 1.60,  val loss 0.312326, percent error 8.40
# Epoch    51, train loss 0.058794, train error 1.38,  val loss 0.313362, percent error 9.00
# Epoch    52, train loss 0.052290, train error 1.30,  val loss 0.313219, percent error 8.50
# Epoch    53, train loss 0.052219, train error 1.38,  val loss 0.312895, percent error 8.20
# Epoch    54, train loss 0.052288, train error 1.20,  val loss 0.321535, percent error 8.60
# Epoch    55, train loss 0.048398, train error 1.03,  val loss 0.316007, percent error 8.50
# Epoch    56, train loss 0.049386, train error 1.07,  val loss 0.321821, percent error 8.60
# Epoch    57, train loss 0.048770, train error 1.15,  val loss 0.324641, percent error 8.10
# Epoch    58, train loss 0.044474, train error 0.90,  val loss 0.321191, percent error 8.70
# Epoch    59, train loss 0.046502, train error 0.97,  val loss 0.311914, percent error 8.10
# Epoch    60, train loss 0.042669, train error 0.78,  val loss 0.318264, percent error 8.00
# Epoch    61, train loss 0.043176, train error 0.95,  val loss 0.320914, percent error 8.30
# Epoch    62, train loss 0.041174, train error 0.70,  val loss 0.328332, percent error 8.30
# Epoch    63, train loss 0.040419, train error 0.80,  val loss 0.330543, percent error 8.20
# Epoch    64, train loss 0.039934, train error 0.82,  val loss 0.327720, percent error 8.50
# Epoch    65, train loss 0.038752, train error 0.65,  val loss 0.325815, percent error 8.10
# Epoch    66, train loss 0.040259, train error 0.75,  val loss 0.322821, percent error 7.60
# Epoch    67, train loss 0.038291, train error 0.65,  val loss 0.330302, percent error 8.40
# Epoch    68, train loss 0.038801, train error 0.68,  val loss 0.329318, percent error 8.20
# Epoch    69, train loss 0.037410, train error 0.65,  val loss 0.327192, percent error 7.80
# Epoch    70, train loss 0.040284, train error 0.93,  val loss 0.348446, percent error 9.10
# Epoch    71, train loss 0.037477, train error 0.78,  val loss 0.338271, percent error 8.80
# Epoch    72, train loss 0.037133, train error 0.72,  val loss 0.338507, percent error 8.90
# Epoch    73, train loss 0.035931, train error 0.70,  val loss 0.329720, percent error 7.90
# Epoch    74, train loss 0.035219, train error 0.65,  val loss 0.334253, percent error 8.20
# Epoch    75, train loss 0.035632, train error 0.60,  val loss 0.338686, percent error 8.50
# Epoch    76, train loss 0.035386, train error 0.65,  val loss 0.341388, percent error 8.30
# Epoch    77, train loss 0.035015, train error 0.60,  val loss 0.339712, percent error 8.60
# Epoch    78, train loss 0.034258, train error 0.47,  val loss 0.338921, percent error 8.20
# Epoch    79, train loss 0.033841, train error 0.57,  val loss 0.344793, percent error 8.60
# Epoch    80, train loss 0.032742, train error 0.53,  val loss 0.339914, percent error 8.50
# Epoch    81, train loss 0.032214, train error 0.47,  val loss 0.341786, percent error 8.10
# Epoch    82, train loss 0.031982, train error 0.50,  val loss 0.340548, percent error 8.20
# Epoch    83, train loss 0.032287, train error 0.50,  val loss 0.344201, percent error 8.50
# Epoch    84, train loss 0.032355, train error 0.57,  val loss 0.346733, percent error 8.30
# Epoch    85, train loss 0.031628, train error 0.38,  val loss 0.341799, percent error 8.20
# Epoch    86, train loss 0.031725, train error 0.43,  val loss 0.344381, percent error 8.30
# Epoch    87, train loss 0.032733, train error 0.57,  val loss 0.349798, percent error 8.50
# Epoch    88, train loss 0.031592, train error 0.53,  val loss 0.342521, percent error 8.30
# Epoch    89, train loss 0.030794, train error 0.40,  val loss 0.344196, percent error 8.20
# Epoch    90, train loss 0.030684, train error 0.47,  val loss 0.344550, percent error 8.30
# Epoch    91, train loss 0.030506, train error 0.43,  val loss 0.345306, percent error 8.50
# Epoch    92, train loss 0.030452, train error 0.43,  val loss 0.345589, percent error 8.00
# Epoch    93, train loss 0.030282, train error 0.45,  val loss 0.348160, percent error 8.30
# Epoch    94, train loss 0.030163, train error 0.32,  val loss 0.346855, percent error 8.40
# Epoch    95, train loss 0.029837, train error 0.43,  val loss 0.347502, percent error 8.10
# Epoch    96, train loss 0.029806, train error 0.40,  val loss 0.351293, percent error 8.50
# Epoch    97, train loss 0.029404, train error 0.38,  val loss 0.350000, percent error 8.30
# Epoch    98, train loss 0.029166, train error 0.35,  val loss 0.349398, percent error 8.40
# Epoch    99, train loss 0.028986, train error 0.35,  val loss 0.347788, percent error 8.40
